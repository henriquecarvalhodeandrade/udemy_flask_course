# %% [markdown]
# Walrus
#
# - esse operador é usado para atribuições de variáveis dentro de expressões
# - permite que você atribua um valor a uma variavel enquanto avalia a expressão
# - É usado com o operador :=

# %%
numeros = [5, 12, 3, 18, 7, 20]

# Filtrando números maiores que 10:
n_maior_10 = [n for n in numeros if(maior := n) > 10]
n_maior_10
# Out:
# [12, 18, 20]

# %%
linhas_processadas = []
with open("texto.txt", 'r', encoding="utf-8") as arquivo:
    for linha in arquivo:
        if (linha_limpa := linha.strip()):
            linhas_processadas.append(linha_limpa)

# %%
linhas_processadas
# Out:
# ['Olá Mundo,',
#  'Esta é uma linha de teste.',
#  'Python é fácil.',
#  'Ruby é interessante.']
